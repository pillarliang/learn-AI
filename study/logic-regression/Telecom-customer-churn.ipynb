# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

churn = pd.read_csv('../data/churn.csv')
churn.head()

churn = pd.get_dummies(churn)
churn.head()

churn.drop(['Churn_No', 'gender_Male'], axis = 1, inplace= True)
churn.head()

churn = churn.rename(columns={'Churn_Yes':'flag'})
churn.columns

churn.flag.value_counts(True)

churn.groupby('flag').mean()
sns.countplot(y='')
# Out:
#        Partner_att  Dependents_att  landline  internet_att  internet_other
# flag
# False     0.528218        0.344801  0.901044      0.379204        0.347700  \
# True      0.357945        0.174425  0.909042      0.245586        0.693954
#
#        StreamingTV  StreamingMovies  Contract_Month  Contract_1YR
# flag
# False     0.365868         0.369927        0.429068      0.252609  \
# True      0.435527         0.437667        0.885500      0.088818
#
#        PaymentBank  PaymentCreditcard  PaymentElectronic  MonthlyCharges
# flag
# False     0.248550           0.249324           0.250097       61.265124  \
# True      0.138042           0.124131           0.573034       74.441332
#
#        TotalCharges  gender_Female
# flag
# False   2545.918081       0.492656
# True    1528.514714       0.502408

# %% [markdown]
# ### 相关接口
# pd.get_dummies()
# https://blog.csdn.net/maymay_/article/details/80198468
#
# pd.drop()
# https://blog.csdn.net/nuaadot/article/details/78304642
#
# value.counts()
# https://zhuanlan.zhihu.com/p/29986906
#
# ground_by()
# https://zhuanlan.zhihu.com/p/101284491

# %%
y = churn['flag']
x = churn[['Contract_Month','internet_other','PaymentElectronic']]

# precessing dataset
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=100)

# train_model
lr = LogisticRegression()
lr.fit(x_train, y_train)

# evaluation
y_pred = lr.predict(x_test)

accuracy_score(y_test, y_pred)
roc_auc_score(y_test, y_pred)
# Out:
# 0.6472872378089588
