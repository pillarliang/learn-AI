# %%
# !pip install paddlepaddle paddleocr
# Out:
# Collecting paddlepaddle
#   Downloading paddlepaddle-2.6.1-cp312-cp312-macosx_10_9_x86_64.whl.metadata (8.6 kB)
# Collecting paddleocr
#   Using cached paddleocr-2.7.3-py3-none-any.whl.metadata (26 kB)
# Requirement already satisfied: httpx in /Users/liangzhu/anaconda3/envs/llm/lib/python3.12/site-packages (from paddlepaddle) (0.27.0)
# Requirement already satisfied: numpy>=1.13 in /Users/liangzhu/anaconda3/envs/llm/lib/python3.12/site-packages (from paddlepaddle) (1.26.4)
# Requirement already satisfied: Pillow in /Users/liangzhu/anaconda3/envs/llm/lib/python3.12/site-packages (from paddlepaddle) (10.3.0)
# Requirement already satisfied: decorator in /Users/liangzhu/anaconda3/envs/llm/lib/python3.12/site-packages (from paddlepaddle) (5.1.1)
# Collecting astor (from paddlepaddle)
#   Using cached astor-0.8.1-py2.py3-none-any.whl.metadata (4.2 kB)
# Collecting opt-einsum==3.3.0 (from paddlepaddle)
#   Using cached opt_einsum-3.3.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: protobuf>=3.20.2 in /Users/liangzhu/anaconda3/envs/llm/lib/python3.12/site-packages (from paddlepaddle) (4.25.3)
# Collecting shapely (from paddleocr)
#   Downloading shapely-2.0.4-cp312-cp312-macosx_10_9_x86_64.whl.metadata (7.0 kB)
# Collecting scikit-image (from paddleocr)
#   Downloading scikit_image-0.23.2-cp312-cp312-macosx_10_9_x86_64.whl.metadata (14 kB)
# Collecting imgaug (from paddleocr)
#   Using cached imgaug-0.4.0-py2.py3-none-any.whl.metadata (1.8 kB)
# Collecting pyclipper (from paddleocr)
#   Downloading pyclipper-1.3.0.post5-cp312-cp312-macosx_10_9_x86_64.whl.metadata (9.0 kB)
# Collecting lmdb (from paddleocr)
#   Using cached lmdb-1.4.1.tar.gz (881 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tqdm in /Users/liangzhu/anaconda3/envs/llm/lib/python3.12/site-packages (from paddleocr) (4.66.2)
# Collecting visualdl (from paddleocr)
#   Using cached visualdl-2.5.3-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: rapidfuzz in /Users/liangzhu/anaconda3/envs/llm/lib/python3.12/site-packages (from paddleocr) (3.8.1)
# Collecting opencv-python<=4.6.0.66 (from paddleocr)
#   Using cached opencv_python-4.6.0.66-cp36-abi3-macosx_10_15_x86_64.whl.metadata (18 kB)
# Collecting opencv-contrib-python<=4.6.0.66 (from paddleocr)
#   Using cached opencv_contrib_python-4.6.0.66-cp36-abi3-macosx_10_15_x86_64.whl.metadata (18 kB)
# Collecting cython (from paddleocr)
#   Downloading Cython-3.0.10-cp312-cp312-macosx_10_9_x86_64.whl.metadata (3.2 kB)
# Requirement already satisfied: lxml in /Users/liangzhu/anaconda3/envs/llm/lib/python3.12/site-packages (from paddleocr) (5.1.0)
# Collecting premailer (from paddleocr)
#   Using cached premailer-3.10.0-py2.py3-none-any.whl.metadata (15 kB)
# Collecting openpyxl (from paddleocr)
#   Downloading openpyxl-3.1.3-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting attrdict (from paddleocr)
#   Using cached attrdict-2.0.1-py2.py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: pyyaml in /Users/liangzhu/anaconda3/envs/llm/lib/python3.12/site-packages (from paddleocr) (6.0.1)
# Requirement already satisfied: python-docx in /Users/liangzhu/anaconda3/envs/llm/lib/python3.12/site-packages (from paddleocr) (1.1.0)
# Requirement already satisfied: beautifulsoup4 in /Users/liangzhu/anaconda3/envs/llm/lib/python3.12/site-packages (from paddleocr) (4.12.3)
# Collecting fonttools>=4.24.0 (from paddleocr)
#   Downloading fonttools-4.53.0-cp312-cp312-macosx_10_9_universal2.whl.metadata (162 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.2/162.2 kB 350.6 kB/s eta 0:00:00a 0:00:01
# Collecting fire>=0.3.0 (from paddleocr)
#   Using cached fire-0.6.0.tar.gz (88 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pdf2docx (from paddleocr)
#   Using cached pdf2docx-0.5.8-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: six in /Users/liangzhu/anaconda3/envs/llm/lib/python3.12/site-packages (from fire>=0.3.0->paddleocr) (1.16.0)
# Collecting termcolor (from fire>=0.3.0->paddleocr)
#   Using cached termcolor-2.4.0-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: soupsieve>1.2 in /Users/liangzhu/anaconda3/envs/llm/lib/python3.12/site-packages (from beautifulsoup4->paddleocr) (2.5)
# Requirement already satisfied: anyio in /Users/liangzhu/anaconda3/envs/llm/lib/python3.12/site-packages (from httpx->paddlepaddle) (4.3.0)
# Requirement already satisfied: certifi in /Users/liangzhu/anaconda3/envs/llm/lib/python3.12/site-packages (from httpx->paddlepaddle) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /Users/liangzhu/anaconda3/envs/llm/lib/python3.12/site-packages (from httpx->paddlepaddle) (1.0.4)
# Requirement already satisfied: idna in /Users/liangzhu/anaconda3/envs/llm/lib/python3.12/site-packages (from httpx->paddlepaddle) (3.6)
# Requirement already satisfied: sniffio in /Users/liangzhu/anaconda3/envs/llm/lib/python3.12/site-packages (from httpx->paddlepaddle) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/liangzhu/anaconda3/envs/llm/lib/python3.12/site-packages (from httpcore==1.*->httpx->paddlepaddle) (0.14.0)
# Requirement already satisfied: scipy in /Users/liangzhu/anaconda3/envs/llm/lib/python3.12/site-packages (from imgaug->paddleocr) (1.12.0)
# Collecting matplotlib (from imgaug->paddleocr)
#   Downloading matplotlib-3.9.0-cp312-cp312-macosx_10_12_x86_64.whl.metadata (11 kB)
# Collecting imageio (from imgaug->paddleocr)
#   Using cached imageio-2.34.1-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: networkx>=2.8 in /Users/liangzhu/anaconda3/envs/llm/lib/python3.12/site-packages (from scikit-image->paddleocr) (3.2.1)
# Collecting tifffile>=2022.8.12 (from scikit-image->paddleocr)
#   Using cached tifffile-2024.5.22-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: packaging>=21 in /Users/liangzhu/anaconda3/envs/llm/lib/python3.12/site-packages (from scikit-image->paddleocr) (23.2)
# Collecting lazy-loader>=0.4 (from scikit-image->paddleocr)
#   Using cached lazy_loader-0.4-py3-none-any.whl.metadata (7.6 kB)
# Collecting et-xmlfile (from openpyxl->paddleocr)
#   Using cached et_xmlfile-1.1.0-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: PyMuPDF>=1.19.0 in /Users/liangzhu/anaconda3/envs/llm/lib/python3.12/site-packages (from pdf2docx->paddleocr) (1.24.1)
# Collecting opencv-python-headless>=4.5 (from pdf2docx->paddleocr)
#   Using cached opencv_python_headless-4.9.0.80-cp37-abi3-macosx_10_16_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: typing-extensions in /Users/liangzhu/anaconda3/envs/llm/lib/python3.12/site-packages (from python-docx->paddleocr) (4.10.0)
# Collecting cssselect (from premailer->paddleocr)
#   Using cached cssselect-1.2.0-py2.py3-none-any.whl.metadata (2.2 kB)
# Collecting cssutils (from premailer->paddleocr)
#   Using cached cssutils-2.11.0-py3-none-any.whl.metadata (8.8 kB)
# Requirement already satisfied: requests in /Users/liangzhu/anaconda3/envs/llm/lib/python3.12/site-packages (from premailer->paddleocr) (2.31.0)
# Requirement already satisfied: cachetools in /Users/liangzhu/anaconda3/envs/llm/lib/python3.12/site-packages (from premailer->paddleocr) (5.3.3)
# Collecting bce-python-sdk (from visualdl->paddleocr)
#   Using cached bce_python_sdk-0.9.11-py3-none-any.whl.metadata (319 bytes)
# Requirement already satisfied: flask>=1.1.1 in /Users/liangzhu/anaconda3/envs/llm/lib/python3.12/site-packages (from visualdl->paddleocr) (3.0.2)
# Collecting Flask-Babel>=3.0.0 (from visualdl->paddleocr)
#   Using cached flask_babel-4.0.0-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: pandas in /Users/liangzhu/anaconda3/envs/llm/lib/python3.12/site-packages (from visualdl->paddleocr) (2.2.1)
# Collecting rarfile (from visualdl->paddleocr)
#   Using cached rarfile-4.2-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: psutil in /Users/liangzhu/anaconda3/envs/llm/lib/python3.12/site-packages (from visualdl->paddleocr) (5.9.8)
# Requirement already satisfied: Werkzeug>=3.0.0 in /Users/liangzhu/anaconda3/envs/llm/lib/python3.12/site-packages (from flask>=1.1.1->visualdl->paddleocr) (3.0.1)
# Requirement already satisfied: Jinja2>=3.1.2 in /Users/liangzhu/anaconda3/envs/llm/lib/python3.12/site-packages (from flask>=1.1.1->visualdl->paddleocr) (3.1.3)
# Requirement already satisfied: itsdangerous>=2.1.2 in /Users/liangzhu/anaconda3/envs/llm/lib/python3.12/site-packages (from flask>=1.1.1->visualdl->paddleocr) (2.1.2)
# Requirement already satisfied: click>=8.1.3 in /Users/liangzhu/anaconda3/envs/llm/lib/python3.12/site-packages (from flask>=1.1.1->visualdl->paddleocr) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in /Users/liangzhu/anaconda3/envs/llm/lib/python3.12/site-packages (from flask>=1.1.1->visualdl->paddleocr) (1.7.0)
# Collecting Babel>=2.12 (from Flask-Babel>=3.0.0->visualdl->paddleocr)
#   Using cached Babel-2.15.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: pytz>=2022.7 in /Users/liangzhu/anaconda3/envs/llm/lib/python3.12/site-packages (from Flask-Babel>=3.0.0->visualdl->paddleocr) (2024.1)
# Requirement already satisfied: PyMuPDFb==1.24.1 in /Users/liangzhu/anaconda3/envs/llm/lib/python3.12/site-packages (from PyMuPDF>=1.19.0->pdf2docx->paddleocr) (1.24.1)
# Requirement already satisfied: pycryptodome>=3.8.0 in /Users/liangzhu/anaconda3/envs/llm/lib/python3.12/site-packages (from bce-python-sdk->visualdl->paddleocr) (3.20.0)
# Collecting future>=0.6.0 (from bce-python-sdk->visualdl->paddleocr)
#   Using cached future-1.0.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting contourpy>=1.0.1 (from matplotlib->imgaug->paddleocr)
#   Downloading contourpy-1.2.1-cp312-cp312-macosx_10_9_x86_64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib->imgaug->paddleocr)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib->imgaug->paddleocr)
#   Using cached kiwisolver-1.4.5-cp312-cp312-macosx_10_9_x86_64.whl.metadata (6.4 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib->imgaug->paddleocr)
#   Using cached pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/liangzhu/anaconda3/envs/llm/lib/python3.12/site-packages (from matplotlib->imgaug->paddleocr) (2.9.0)
# Requirement already satisfied: tzdata>=2022.7 in /Users/liangzhu/anaconda3/envs/llm/lib/python3.12/site-packages (from pandas->visualdl->paddleocr) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/liangzhu/anaconda3/envs/llm/lib/python3.12/site-packages (from requests->premailer->paddleocr) (2.1.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/liangzhu/anaconda3/envs/llm/lib/python3.12/site-packages (from requests->premailer->paddleocr) (2.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/liangzhu/anaconda3/envs/llm/lib/python3.12/site-packages (from Jinja2>=3.1.2->flask>=1.1.1->visualdl->paddleocr) (2.1.5)
# Downloading paddlepaddle-2.6.1-cp312-cp312-macosx_10_9_x86_64.whl (80.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.2/80.2 MB 2.4 MB/s eta 0:00:0000:0100:01
# Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Using cached paddleocr-2.7.3-py3-none-any.whl (780 kB)
# Downloading fonttools-4.53.0-cp312-cp312-macosx_10_9_universal2.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 4.2 MB/s eta 0:00:0000:0100:01
# Using cached opencv_contrib_python-4.6.0.66-cp36-abi3-macosx_10_15_x86_64.whl (56.1 MB)
# Using cached opencv_python-4.6.0.66-cp36-abi3-macosx_10_15_x86_64.whl (46.4 MB)
# Using cached astor-0.8.1-py2.py3-none-any.whl (27 kB)
# Using cached attrdict-2.0.1-py2.py3-none-any.whl (9.9 kB)
# Downloading Cython-3.0.10-cp312-cp312-macosx_10_9_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 5.0 MB/s eta 0:00:0000:0100:01
# Using cached imgaug-0.4.0-py2.py3-none-any.whl (948 kB)
# Downloading scikit_image-0.23.2-cp312-cp312-macosx_10_9_x86_64.whl (14.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.0/14.0 MB 2.9 MB/s eta 0:00:0000:0100:01
# Downloading openpyxl-3.1.3-py2.py3-none-any.whl (251 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 251.3/251.3 kB 2.3 MB/s eta 0:00:0000:0100:01
# Using cached pdf2docx-0.5.8-py3-none-any.whl (132 kB)
# Using cached premailer-3.10.0-py2.py3-none-any.whl (19 kB)
# Downloading pyclipper-1.3.0.post5-cp312-cp312-macosx_10_9_x86_64.whl (145 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.9/145.9 kB 1.9 MB/s eta 0:00:0000:010:01
# Downloading shapely-2.0.4-cp312-cp312-macosx_10_9_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 2.8 MB/s eta 0:00:0000:0100:01
# Using cached visualdl-2.5.3-py3-none-any.whl (6.3 MB)
# Using cached flask_babel-4.0.0-py3-none-any.whl (9.6 kB)
# Using cached imageio-2.34.1-py3-none-any.whl (313 kB)
# Using cached lazy_loader-0.4-py3-none-any.whl (12 kB)
# Using cached opencv_python_headless-4.9.0.80-cp37-abi3-macosx_10_16_x86_64.whl (55.7 MB)
# Using cached tifffile-2024.5.22-py3-none-any.whl (225 kB)
# Using cached bce_python_sdk-0.9.11-py3-none-any.whl (342 kB)
# Using cached cssselect-1.2.0-py2.py3-none-any.whl (18 kB)
# Using cached cssutils-2.11.0-py3-none-any.whl (398 kB)
# Using cached et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Downloading matplotlib-3.9.0-cp312-cp312-macosx_10_12_x86_64.whl (7.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 3.5 MB/s eta 0:00:0000:0100:01
# Using cached rarfile-4.2-py3-none-any.whl (29 kB)
# Using cached termcolor-2.4.0-py3-none-any.whl (7.7 kB)
# Using cached Babel-2.15.0-py3-none-any.whl (9.6 MB)
# Downloading contourpy-1.2.1-cp312-cp312-macosx_10_9_x86_64.whl (263 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 263.3/263.3 kB 2.3 MB/s eta 0:00:00a 0:00:01
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached future-1.0.0-py3-none-any.whl (491 kB)
# Using cached kiwisolver-1.4.5-cp312-cp312-macosx_10_9_x86_64.whl (67 kB)
# Using cached pyparsing-3.1.2-py3-none-any.whl (103 kB)
# Building wheels for collected packages: fire, lmdb
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.6.0-py2.py3-none-any.whl size=117031 sha256=217cd3ccdac8a5f38b5067f5996f37e715caa1a06ccbb7dd3c6b387c6c47c1c0
#   Stored in directory: /Users/liangzhu/Library/Caches/pip/wheels/97/4a/3f/f6f222440f03d888f026ac848b6b4ea57183ebfcd8f3cb8904
#   Building wheel for lmdb (setup.py) ... done
#   Created wheel for lmdb: filename=lmdb-1.4.1-cp312-cp312-macosx_10_9_x86_64.whl size=96815 sha256=8256961314e6e553d0f892f3493817093f73a771602107e242527389b39ef61b
#   Stored in directory: /Users/liangzhu/Library/Caches/pip/wheels/26/9d/7e/cab9d5721ebc8f2319ab66600b9cdd02a903065558b05debe3
# Successfully built fire lmdb
# Installing collected packages: pyclipper, lmdb, tifffile, termcolor, shapely, rarfile, pyparsing, opt-einsum, opencv-python-headless, opencv-python, opencv-contrib-python, lazy-loader, kiwisolver, imageio, future, fonttools, et-xmlfile, cython, cycler, cssutils, cssselect, contourpy, Babel, attrdict, astor, scikit-image, premailer, openpyxl, matplotlib, fire, bce-python-sdk, pdf2docx, paddlepaddle, imgaug, Flask-Babel, visualdl, paddleocr
# Successfully installed Babel-2.15.0 Flask-Babel-4.0.0 astor-0.8.1 attrdict-2.0.1 bce-python-sdk-0.9.11 contourpy-1.2.1 cssselect-1.2.0 cssutils-2.11.0 cycler-0.12.1 cython-3.0.10 et-xmlfile-1.1.0 fire-0.6.0 fonttools-4.53.0 future-1.0.0 imageio-2.34.1 imgaug-0.4.0 kiwisolver-1.4.5 lazy-loader-0.4 lmdb-1.4.1 matplotlib-3.9.0 opencv-contrib-python-4.6.0.66 opencv-python-4.6.0.66 opencv-python-headless-4.9.0.80 openpyxl-3.1.3 opt-einsum-3.3.0 paddleocr-2.7.3 paddlepaddle-2.6.1 pdf2docx-0.5.8 premailer-3.10.0 pyclipper-1.3.0.post5 pyparsing-3.1.2 rarfile-4.2 scikit-image-0.23.2 shapely-2.0.4 termcolor-2.4.0 tifffile-2024.5.22 visualdl-2.5.3

# %%
import os
import fitz  # pip install PyMuPDF
from tqdm import tqdm
import numpy as np
import base64
from paddleocr import PaddleOCR


def pdf_ocr_txt(filepath, dir_path="tmp_files"):
    full_dir_path = os.path.join(os.path.dirname(filepath), dir_path)
    if not os.path.exists(full_dir_path):
        os.makedirs(full_dir_path)
    doc = fitz.open(filepath)
    txt_file_path = os.path.join(full_dir_path, "{}.txt".format(os.path.split(filepath)[-1]))
    img_name = os.path.join(full_dir_path, 'tmp.png')
    with open(txt_file_path, 'w', encoding='utf-8') as fout:
        for i in tqdm(range(doc.page_count)):
            page = doc.load_page(i)
            pix = page.get_pixmap() # 将 PDF 页面转换成一个图像
            img = np.frombuffer(pix.samples, dtype=np.uint8).reshape((pix.h, pix.w, pix.n))

            img_data = {"img64": base64.b64encode(img).decode("utf-8"), "height": pix.h, "width": pix.w,
                        "channels": pix.n}
            result = ocr(img_data)
            result = [line for line in result if line]
            ocr_result = [i[1][0] for line in result for i in line]
            fout.write("\n".join(ocr_result))
    if os.path.exists(img_name):
        os.remove(img_name)
    return txt_file_path


def ocr(img_data):
    # 初始化 PaddleOCR 引擎
    ocr_engine = PaddleOCR(use_angle_cls=True, lang="ch", use_gpu=True, show_log=False, type='structure')

    img_file = img_data['img64']
    height = img_data['height']
    width = img_data['width']
    channels = img_data['channels']

    binary_data = base64.b64decode(img_file)
    img_array = np.frombuffer(binary_data, dtype=np.uint8).reshape((height, width, channels))

    # 无文件上传，返回错误
    if not img_file:
        return 'error: No file was uploaded.'

    # 调用 PaddleOCR 进行识别
    res = ocr_engine.ocr(img_array)

    # 返回识别结果
    return res

# %%
pdf_path = '../data/表格.pdf'
res = pdf_ocr_txt(pdf_path)
print(res)
# Out:
# 100%|██████████| 2/2 [00:24<00:00, 12.35s/it]
# ../data/tmp_files/表格.pdf.txt
